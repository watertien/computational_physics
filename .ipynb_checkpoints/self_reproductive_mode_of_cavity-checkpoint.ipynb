# %%
# %load cp_imports.py
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Use retina backend for better figures
# %config InlineBackend.figure_format = 'retina'

# %%
# %matplotlib notebook
from matplotlib import animation


def transverse_mode(*args, **kwargs):
    """
    Calculate transverse laser mode after every round-strip
    
    """
    total_time = 400 # Totoal round-strip time 
    wavelength = 1030e-9  # Unit: m
    cavitylength = 1. 
    k = 2 * np.pi / wavelength
    recurrence_coefficient = 1j / (wavelength * cavitylength)  

    x = np.linspace(-2, 2, 100) * 1e-3 # x value of points on mirror  
    dx = x[1] - x[0]
    # y = np.linspace(-2, 2, 1000)
    # xx, yy = np.meshgrid(x, y)
    # Initial transverse mode of incident wave  
    u_prev = np.ones_like(x, dtype="complex")
    u_next = np.zeros_like(u_initial)
    
    for _ in range(total_time):
        for m, n in enumerate(x):
            u_next[m] = np.sum(recurrence_coefficient * u_initial\
                               * np.exp(-1j * k * (n - x))) * dx
        ax.set_data(x, u_next)
        yield line, 
        u_initial = u_next



# u = transverse_mode()
strip = np.linspace(-2, 2, 100) * 1e-3

fig, ax = plt.subplots()
line, = ax.plot([], [])

frame_iterator = transverse_mode()
frame_update = lambda i: next(frame_iterator)

ani = animation.FuncAnimation(fig, frame_update, interval=300)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
np.ones((2, 2), dtype="complex")
# Out:
# array([[1.+0.j, 1.+0.j],
#        [1.+0.j, 1.+0.j]])
