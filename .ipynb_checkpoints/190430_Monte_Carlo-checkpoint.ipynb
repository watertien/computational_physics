# %%
# %load cp_imports.py
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
import pandas as pd
# Use retina backend for better figures
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Pseudorandom Number
#
# **Linear congruential generator**
# \begin{equation}
#     x' = (ax + c) \ \text{mod}\ m
# \end{equation}
#
# (Save produced data into a file for debugging.)

# %%
def dice_roller():
    return np.random.randint(0, 7)

count = 0
n = 100
for _ in range(n):
    if dice_roller() == 6 and dice_roller() == 1:
        count += 1
print(f"{(count/n - 1/36) * 36}")

# %% [markdown]
# # Sampling Method
#
# Given a series of uniform distribution between 0~1, how to generate arbitrary distribution set?
#
# 1. calculate $F(x)$(CDF)
# 1. generate $\lambda$ from (0, 1)uniform distribution
# 1. solve $F(x) = \lambda$
#
# Or **Metropolis–Hastings** in MCMC
#
# 1. choose random number $x$ on domain of $f(x)$
# 1. compare $x$ with $f(x)/M$
# 1. if $x$ is greater, accept; if $x$ is smaller, reject.

# %% [markdown]
# # Seed Function

# %% [markdown]
# # Nuclear Decay

# %%
N_Tl = 1000
N_Pb = 0
dt = 1
tau = 3.053 * 60
p = 1 - 2**(-dt / tau) # Decay probobility in dt
t = 0
t_end = 1000
_t = np.arange(0, t_end, dt)
decay_number = np.zeros_like(_t, dtype="int")

for i, j in enumerate(_t):
    decay_proposal = np.random.random(size=_t.size-np.sum(decay_number)) # For survival atoms
    decay_number[i] = np.sum(decay_proposal < p)
    
plt.plot(_t, N_Pb + np.cumsum(decay_number), label='Pb')
plt.plot(_t, N_Tl - np.cumsum(decay_number), label='Tl')
plt.legend()

# %% [markdown]
# # Brownian Motion

# %%
# Initial position (0, 0)
t = 0
dt = 1
t_end = 100
t_size = (t_end - t)//dt
_t = np.arange(t, t_end, dt)
particle_n = 10
particles = np.zeros(particle_n, dtype='int') # 1-D random walking
history = np.zeros((t_size, particle_n))

for i, j in enumerate(_t):
    walking = np.random.choice([-1, 1], size=particle_n)
    particles = particles + walking
    history[i] = particles
    t += dt

plt.plot(_t, np.mean(history**2, axis=1)**0.5, 'p', alpha=.4);

plt.plot(_t, _t**0.5, '--', alpha=.4);

# %%
# %matplotlib notebook
from matplotlib import animation
# Initial position (0, 0)
t = 0
dt = 1
t_end = 100
t_size = (t_end - t)//dt
_t = np.arange(t, t_end, dt)
particle_n = 10
particles = np.zeros((particle_n, 2), dtype='int') # 2-D random walking


def frame_iter():
    global particles
    for i, j in enumerate(_t):
        walking = np.random.choice([-1, 1], size=(particle_n, 2))
        particles = particles + walking
        line.set_data(particles.T)
        yield line,
        
fig, ax = plt.subplots()
ax.set_xlim(-t_end, t_end)
ax.set_ylim(-t_end, t_end)
ax.grid(True)
ax.set_aspect("equal")
line, = ax.plot([], [], 'ro')
_frame = frame_iter()
update = lambda i: next(_frame)
ani = animation.FuncAnimation(fig, update, frames=t_size, interval=100, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # Definite Integral
#
# Sampling from a multidimensional domain, calculate integrand value(use $n-1$ dimensions)
# at every sample point, compare random value and  integrand value(use $n$-th dimension) to
# decide whether to accept it. Finally, calculate ratio as probability.
# Sampling scheme is often problem-specific.

# %%
def integrand(x):
    return np.sin(x * (x-2)) + 1


x0, x1 = 0, 10
sample_n = 100000
sample_x = np.random.random(size=sample_n) * (x1 - x0) + x0  # Uniform sampling
sample_y = np.random.random(size=sample_n) * 2
mask = sample_y < integrand(sample_x)
below = np.sum(mask)
area = (x1 - x0) * 2
result = below / sample_n * area 
x = np.linspace(0, 10, 1000)
print(result)

plt.plot(x, integrand(x))
plt.plot(sample_x[mask], sample_y[mask], 'ro')
plt.plot(sample_x[np.logical_not(mask)], sample_y[np.logical_not(mask)], 'bp', alpha=.2)
# Out:
# 9.1986

# %%
def integrand(x):
    return np.sin(1 / (x * (2 - x)))**2


x0, x1 = 0.01, 1.99
sample_n = 100000
sample_x = np.random.random(size=sample_n) * (x1 - x0) + x0  # Uniform sampling
mean_y = np.mean(integrand(sample_x))

result = mean_y * (x1 - x0) 
x = np.linspace(x0, x1, 1000)
print(result)

plt.plot(x, integrand(x))
# Out:
# 1.441219482115607

# %% [markdown]
# # Importance Sampling
#
# Sampling from a given distribution that below the integrand function.
# \begin{equation}
# <f(x)>={\frac  {1}{N}}\,\sum _{{i=1}}^{N} \frac{f(x_i)}{p(x_i)}
# \end{equation}
# Choose appropriate model for sampling to avoid .

# %% [markdown]
# # Maxwell Speed Distribution

# %%
def collision(v1, v2):
    """
    Simulate collision of two molecules
    with speed v1, v2, respectively.
    
    return new speed of two molecules 
    """
    alpha = np.random.random() * 2 * np.pi
    gamma = np.random.random() * 2 * np.pi   
    _v1 = 0.5 * (v1**2 + v2**2) \
                + (0.5 * (v1**2 - v2**2) * np.cos(gamma)
                   + 0.5 * v1 * v2 * np.sin(alpha) * np.sin(gamma))
    _v2 = 0.5 * (v1**2 + v2**2) \
                - (0.5 * (v1**2 - v2**2) * np.cos(gamma)
                   + 0.5 * v1 * v2 * np.sin(alpha) * np.sin(gamma))
    return _v1**0.5, _v2**0.5


ctimes = 10**6
particle_num = 10**5
v_mean = 10
particle = np.random.randn(particle_num) + v_mean


for _ in range(ctimes):
    # Randomly select two molecules 
    n1, n2 = np.random.randint(0, particle.size, size=2)
    particle[[n1, n2]] = collision(*particle[[n1, n2]])
    
plt.hist(particle, bins=100);

# %% [markdown]
# # Ising Model

# %%
# atom number along x/y direction,
# After some tests, the final phase transition result
# is more sensitive to atom number rather than sweep
# time, which means the system can get to equilibrium
# state quite quickly with several steps.
n = 50
mag = np.ones((n, n))
J = 1.
k = 1

total_mag = np.sum(mag)
total_energy = 0
for i, row in enumerate(mag):
    for j, atom in enumerate(row):
        # Only include right and upper adjacents
        total_energy += - J * atom * (mag[(i + 1) % n, j] + mag[i, (j + 1) % n])

temp = 0.1
dT = 1e-1
temp_end = 5
equilibrium_n = 80
energys = [total_energy]
mags = [total_mag]

while temp < temp_end:
    for _ in range(equilibrium_n):
       # Ensure after n loops, system has been in equilibrium state
        for i in range(n):
            for j in range(n):
               # old mag[i,j]
                dE = J * 2 * mag[i,j] * (mag[(i + 1) % n, j] + mag[i, (j + 1) % n]\
                                       + mag[(i - 1) % n, j] + mag[i, (j - 1) % n])
                if dE < 0 or np.random.random() < np.exp(-dE / k / temp):
                    # new mag[i,j] 
                    mag[i, j] = - mag[i, j]
                    total_energy += dE
                    total_mag += 2 * mag[i, j]

    energys.append(total_energy)
    mags.append(total_mag)
    temp += dT

plt.subplot(211)
plt.title("Magnetic Moment")
plt.plot(np.arange(0.1, temp_end+dT, dT), mags[:-1], 'ro')
plt.axvline(x=2.27)
plt.subplot(212)
plt.title("Energy")
plt.axvline(x=2.27)
plt.plot(np.arange(0.1, temp_end+dT, dT), energys[:-1], 'bo')

# %% [markdown]
# # Internal Energy of Quantum Gas
#
# Randomly increase or decrease quantum number of
# an arbitrary particle by one, and calculate new energy
# after change. Decide whether to accept this proposal
# by Metropolis algorithm.

# %%
particle_n = 100 # Particle quantity
state = np.ones((particle_n, 3), dtype="int") 
kinetic = np.pi**2 / 2 * np.sum(state**2) 
k = 1.
temp = 1e3 # Initial temperature

equilibrium_n = 500000
energys = np.zeros(equilibrium_n)

dE = 0
for i in range(equilibrium_n):
    # Ensure after n loops, system has been in equilibrium state
    particle = np.random.randint(0, particle_n)
    direction = np.random.randint(0, 3)
    change = (-1)**np.random.randint(0, 2)
    if state[particle,direction] > 1 or change == 1:
        dE = (2 * state[particle, direction] * change + 1) * np.pi**2 / 2 
        if dE < 0 or np.random.random() < np.exp(-dE / k / temp):
            # Accept proposal
            state[particle,direction] += change
            kinetic += dE      
    energys[i] = kinetic

plt.plot(energys/particle_n)

# %%
dE
# Out:
# 54.28282420599147

# %% [markdown]
# # Solve Schrodinger Equation
#
# Use variational method to solve ground eigenstate
# of a given system.
#
# 1. First discretization of the area to be solved
# 1. Randomly change value of a point, calculate new energy
# 1. Use Metropolis algorithms to decide whether to accept
# 1. Repeat step 1-3 until get to a high temperature
#
# Note for normalization after every modification.

# %%
N = 15
dx = 10 / (N - 1)
x = np.arange(-5, 5, dx) # According to Nyquist sampling, f_sampling > 2 * f_signal
# Guess a initial distribution
phi = np.ones_like(x, dtype="float")
phi[[0,-1]] = 0 # Set infinite boundary condition 
phi = phi / np.trapz(phi**2, x=x)**0.5
hbar = 1.
m = 1.
equilibrium_n = 1000

phis = np.zeros((equilibrium_n, phi.size), dtype="float")


def hamilton(arr, dx):
    """
    Hamiltonian of the zero-centered harmonic potential
    """
    diff2 = np.zeros_like(arr)
    diff2[1:-1] = (arr[:-2] - 2 * arr[1:-1] + arr[2:]) / dx**2 # Second order difference 
    diff2[[0,-1]] = 0 # Infinite zero boundary
    # Set omega to 1
    _hamilton = -hbar**2 / (2 * m) * diff2 + 1/2 * m * x**2
    return np.sum(arr[1:-1] * _hamilton[1:-1]) * dx


for i in range(equilibrium_n):
    # Randomly alter an intermediate point, increase or decrease 
    candidate = np.random.randint(1, x.size-1)
    change = np.random.uniform(0.8, 1.2)
    temp = np.copy(phi)
    temp[candidate] *= change
    temp = temp / np.trapz(temp**2, x=x)**0.5  # Normalization 
    dE = hamilton(temp, dx) - hamilton(phi, dx)
    # dE = (-2 / dx**2 + phi[candidate]) * (change - 1) * phi[candidate]
    if dE < 0:
        phi[:] = temp[:] 
    phis[i] = phi

plt.plot(x, phis[0,:], 'ro-')
plt.plot(x, phis[-1,:], 'bs-')

# %% [markdown]
# # Annealing and Monte Carlo

# %% [markdown]
# # Model Fitting
#
# Find parameter set to minimize $\chi^2$ function.
# \begin{equation}
#     \chi^2 = \sum_{i=0}^{N-1} \frac{\left[y_i - f(x_i;\alpha)\right]^2}{\sigma_i^2}
# \end{equation}
#
# * Freedom of a model.

# %%
def chi_square(x, y, sigma, model, *parameters):
    """
    Calculate chi-square value of given parameters of a model
    
    x: observed x data
    y: observed y data
    sigma: uncertainties of observation 
    model: model to be calculated
    parameters: optimized fitting parameters 
    
    """
    chi2 = np.sum((y - model(x, *parameters))**2 / sigma**2)
    return chi2


def fit_Gaussian(x, y, sigma_y):
    '''
    x: x data, 1-D ndarray of size N 
    y: y data, 1-D ndarray of size N
    sigma_y: covariance matrix of y, 2-D array of shape (N, N)
    
    return best-fit slope and intersect with their uncertainties 
    '''
    # Set x, y to column vector
    x = x.reshape((-1, 1))
    y = y.reshape((-1, 1))

    # Construct needed matrics
    A = np.concatenate((np.ones_like(x), x), axis=1)
    
    _left = np.matmul(np.matmul(A.T, sigma_y.I), A).I
    _right = np.matmul(np.matmul(A.T, sigma_y.I), y)
    b, m = np.array(np.matmul(_left, _right))
    fit_cov = np.array(_left)
    return b, m, fit_cov


data = np.genfromtxt("data/week12_data_fitting.txt", delimiter=' ')
x = data[:, 0]
y = data[:, 1]
sigma = data[:, 2]

# %%
sigma_y = np.matrix(np.diag(sigma))
b, m, fit_cov = fit_Gaussian(x, y, sigma_y)
foo = np.linspace(0, 1)
plt.errorbar(x, y, yerr=sigma,
            marker="o", capsize=3, linestyle=" ")
plt.plot(foo, m * foo + b)
print(chi_square(x, y, sigma, lambda x,M,B: M*x+B, m,b))
# Out:
# 13099.925977606074

# %%
from scipy.optimize import curve_fit


def polynomial_2nd(x, a, b, c):
    return a + b * x + c * x**2 


def my_exp(x, a, b, c):
    return a + b * np.exp(-c * x)


popt = np.zeros((2, 3), dtype="float")
popt[0], _ = curve_fit(polynomial_2nd, x, y, sigma=sigma)
popt[1], _ = curve_fit(my_exp, x, y, sigma=sigma)

plt.errorbar(x, y, yerr=sigma, alpha=.3,
            marker="o", capsize=3, linestyle=" ")
plt.plot(foo, polynomial_2nd(foo, *popt[0]), 'r--')
plt.plot(foo, my_exp(foo, *popt[1]), 'k-')

print(chi_square(x, y, sigma, polynomial_2nd, *popt[0]))
print(chi_square(x, y, sigma, my_exp, *popt[1]))
# Out:
# 595.9224414550821
# 93.87021441841691

# %%
popt
# Out:
# array([[ 2.7996136 , -3.98272106,  2.35010229],
#        [ 0.99949411,  1.90160017,  2.99351778]])

# %% [markdown]
# # EMCEE

# %%
# Choose the "true" parameters.
m_true = -0.9594
b_true = 4.294
f_true = 0.534

# Generate some synthetic data from the model.
N = 50
x = np.sort(10*np.random.rand(N))
yerr = 0.1 + 0.5 * np.random.rand(N)
y = m_true * x + b_true
y += np.abs(f_true * y) * np.random.randn(N)
y += yerr * np.random.randn(N)
